# %%
import pandas as pd

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)
filepath = "D:\data\hol_panel\MPNWAVE7_DAGBOEKdata.sav"
df = pd.read_spss(filepath)

# %%
df['SAMENREIZEN'].value_counts()
# Out:
# travelled alone                               32681
# travelled together with 1 person              13248
# travelled together with 2 persons              4076
# On this day the person did not take a trip     3619
# travelled together with 3 persons              2015
# travelled together with 4 persons               657
# travelled together with more than 5 people      424
# travelled together with 5 persons               209
# Name: SAMENREIZEN, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57457 entries, 0 to 57456
# Data columns (total 86 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   PERSOON                      57457 non-null  category
#  1   HHID                         57457 non-null  float64
#  2   PERSID                       57457 non-null  float64
#  3   HH_VALID                     57457 non-null  category
#  4   IMPHHDATA                    57457 non-null  category
#  5   P_VALID                      57457 non-null  category
#  6   JAAR                         57457 non-null  float64
#  7   VPLID                        53838 non-null  float64
#  8   WEGGEWEEST                   57457 non-null  category
#  9   VERTREKP                     57457 non-null  category
#  10  AANTVPL                      57457 non-null  category
#  11  VPLDAGNR                     57457 non-null  category
# ...
