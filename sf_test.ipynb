# %%
from exp.get_graph import get_graph

G,nodes_dict = get_graph()

# 重新导入需要的类和函数
from exp.agent import Agent, Activity, Action,Journey

# %%
for u, v, data in G.edges(data=True):
    print(u,v,data)

# %%
from exp.traffic import Traffic_State

tf = Traffic_State(G)
tf.road_segments

# %%
from exp.Env import Env

env = Env(G, nodes_dict,4,mode="no")
schedule=[Activity.HOME,Activity.WORK, Activity.LEISURE, Activity.SHOPPING]
# Out:
# Home Node: Node(id=1,type=NodeType.HOME) generated.
# Home Node: Node(id=2,type=NodeType.HOME) generated.
# Home Node: Node(id=7,type=NodeType.HOME) generated.
# Home Node: Node(id=12,type=NodeType.HOME) generated.
# Home Node: Node(id=13,type=NodeType.HOME) generated.
# Home Node: Node(id=18,type=NodeType.HOME) generated.
# Home Node: Node(id=20,type=NodeType.HOME) generated.
# Action space: [1, 2, 3, 6, 4, 12, 5, 11, 9, 8, 7, 18, 16, 10, 15, 17, 14, 13, 24, 23, 19, 22, 20, 21]
#
#      ██████╗ ███████╗███╗   ██╗
#     ██╔════╝ ██╔════╝████╗  ██║
#     ██║  ███╗█████╗  ██╔██╗ ██║
#     ██║   ██║██╔══╝  ██║╚██╗██║
#     ╚██████╔╝███████╗██║ ╚████║
#      ╚═════╝ ╚══════╝╚═╝  ╚═══╝
#
# ___________________env created__________________________
# 100%|██████████| 5552640/5552640 [00:16<00:00, 340704.05it/s]
# ___________________rl initiate__________________________
# ___________________traffic state initiate________________
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 env = Env(G, nodes_dict,4,mode="no")
#       4 schedule=[Activity.HOME,Activity.WORK, Activity.LEISURE, Activity.SHOPPING]
# ----> 5 env.generate_agent(schedule,1)
#
# TypeError: generate_agent() missing 1 required positional argument: 'home'

# %%
env.generate_agent(schedule,1)

# %%
from exp.q import epsilon_greedy_policy

epsilon_greedy_policy(env,env.Q_table,env.step_in_sim(),0.1)

# %%
env.agents[0].state

# %%
env.end()

# %%
# 假设env.utility是一个字典，其值是分数
# 先从字典中提取所有分数的列表
utility_scores = list(env.utility.values())

# 使用matplotlib绘制直方图
import numpy as np
import matplotlib.pyplot as plt

plt.hist(utility_scores, bins=20)  # bins参数可以根据需要调整
plt.xlabel('Utility Score')
plt.ylabel('Frequency')
plt.title('Distribution of Utility Scores')
plt.show()

# %%
env.agents[0].state

# %%
env.agents[993].state

# %%
env.agents[973].state

# %%
#utility_scores的最大值
max(utility_scores)

# %%
env.reset()

# %%
env.agents[0].state

# %%
env

# %%
from exp.q import q_learning

epsilon = 0.8
alpha = 0.01
gamma = 0.99
num_episodes = 10000
q_table = q_learning(env, num_episodes, alpha, gamma, epsilon)
